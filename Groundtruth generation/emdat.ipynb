# %% [markdown]
# # EXTRACT EVENTS FROM EM-DAT
#
# Database downloaded using an account at https://www.emdat.be/

# %%
import pandas as pd
import numpy as np
import requests
import json
import datetime
import re
import io
import csv
import os

# %%
def import_file_as_dataframe(FILENAME, path):
    
    INPUT_FILE = path + FILENAME
    
    #Read data from file without converting dates
    with open(INPUT_FILE) as f:
        data = json.load(f)
        data = pd.DataFrame(data)

    return data

# %%
# Changing format to emdat dataframes
def format_emdat(data):
    
    data['start_date'] = pd.to_datetime(data['start_date'], format='%d/%m/%Y', errors='coerce')
    data['end_date'] = pd.to_datetime(data['end_date'], format='%d/%m/%Y', errors='coerce')
    data.index = data.pop('start_date')
    
    return data

# %%
data = import_file_as_dataframe('2019.json', './data/databases')
data = format_emdat(data)
data.head()
# Out:
#              end_date country_name  iso                              location  \
# start_date
# 2018-05-09 2018-05-22  Afghanistan  AFG
# 2018-07-12 2018-07-12  Afghanistan  AFG             khenj district (Panjshir)
# 2018-05-07 2018-05-15  Afghanistan  AFG
# 2018-07-12 2018-07-12  Afghanistan  AFG   Peshghor (Khenj district, Panjshir)
# 2018-08-24 2018-08-24  Afghanistan  AFG  Ghazi-Abad district (Kunar province)
#
#            latitude longitude dis_mag_value dis_mag_scale   dis_type  \
# start_date
# 2018-05-09    34.94    68.216      184396.9           Km2      Flood
# 2018-07-12                                                 Landslide
# 2018-05-07                                            Km2      Flood
# 2018-07-12                                                 Landslide
# 2018-08-24                                            Km2      Flood
#
#             dis_subtype total_deaths total_affected total_dam insured_losses  \
# start_date
# 2018-05-09           --           72           4000         0              0
# 2018-07-12     Mudslide           12              0         0              0
# 2018-05-07           --           18              0         0              0
# 2018-07-12     Mudslide           10           2750         0              0
# 2018-08-24  Flash flood           11              0         0              0
#
#            event_name disaster_no associated_dis associated_dis2
# start_date
# 2018-05-09              2018-0156             --              --
# 2018-07-12              2018-0189             --              --
# 2018-05-07              2018-0212             --              --
# 2018-07-12              2018-0242             --              --
# 2018-08-24              2018-0350             --              --

# %%
data = data.drop(columns=['associated_dis2', 'dis_mag_scale', 'iso', 'dis_type', 'insured_losses', 'total_dam', 'event_name'])

# %%
data.head()
# Out:
#              end_date country_name                              location  \
# start_date
# 2018-05-09 2018-05-22  Afghanistan
# 2018-07-12 2018-07-12  Afghanistan             khenj district (Panjshir)
# 2018-05-07 2018-05-15  Afghanistan
# 2018-07-12 2018-07-12  Afghanistan   Peshghor (Khenj district, Panjshir)
# 2018-08-24 2018-08-24  Afghanistan  Ghazi-Abad district (Kunar province)
#
#            latitude longitude dis_mag_value  dis_subtype total_deaths  \
# start_date
# 2018-05-09    34.94    68.216      184396.9           --           72
# 2018-07-12                                      Mudslide           12
# 2018-05-07                                            --           18
# 2018-07-12                                      Mudslide           10
# 2018-08-24                                   Flash flood           11
#
#            total_affected disaster_no associated_dis
# start_date
# 2018-05-09           4000   2018-0156             --
# 2018-07-12              0   2018-0189             --
# 2018-05-07              0   2018-0212             --
# 2018-07-12           2750   2018-0242             --
# 2018-08-24              0   2018-0350             --

# %%
data = data.sort_values(by='start_date')

# %%
list(data.columns.values)
# Out:
# ['end_date',
#  'country_name',
#  'location',
#  'latitude',
#  'longitude',
#  'dis_mag_value',
#  'dis_subtype',
#  'total_deaths',
#  'total_affected',
#  'disaster_no',
#  'associated_dis']

# %%
data.rename(columns={'country_name': 'countries', 'total_deaths': 'deaths', 'dis_mag_value': 'area', 'longitude': 'long', 'latitude': 'lat', 'disaster_no': 'id_emdat', 'dis_subtype': 'type', 'total_affected': 'affected', 'associated_dis': 'cause', 'location': 'locations'}, inplace=True)
data.rename_axis('start_date', inplace=True)

data.head()
# Out:
#              end_date                               countries  \
# start_date
# 2018-01-01 2018-01-05                                Malaysia
# 2018-01-03 2018-01-07  Congo (the Democratic Republic of the)
# 2018-01-08 2018-01-14          United States of America (the)
# 2018-01-13 2018-01-17                       Philippines (the)
# 2018-01-13 2018-01-22                                Paraguay
#
#                                                     locations      lat  \
# start_date
# 2018-01-01   Kuantan, Rompin, Pekan, Jerantut, Lipis, Bera...  365.883
# 2018-01-03  Galiema, Bandalungwa, Selembao, Masina, Limete...   -4.355
# 2018-01-08  Santa Barbara County (Montecito and Carpinteri...
# 2018-01-13  Bicol, Dvao, Eastern Visayas, NOrthern Mindana...
# 2018-01-13                Bañado Norte, Chacarita, Bañado Sur  -25.312
#
#                long       area            type deaths affected   id_emdat  \
# start_date
# 2018-01-01  102.337  117492.07              --      2    12000  2018-0068
# 2018-01-03   15.116    5597.13              --     51    15760  2018-0005
# 2018-01-08                            Mudslide     21     1366  2018-0010
# 2018-01-13                                  --     11   180000  2018-0051
# 2018-01-13  -57.599    2924.11  Riverine flood      0     5000  2018-0066
#
#                                     cause
# start_date
# 2018-01-01                             --
# 2018-01-03  Slide (land, mud, snow, rock)
# 2018-01-08                          Flood
# 2018-01-13                             --
# 2018-01-13                             --

# %%
data['in_emdat'] = 1 #Source identifier for future merging

# %%
outfile = './data/databases/emdat.csv'
data.to_csv(outfile, sep=',')
