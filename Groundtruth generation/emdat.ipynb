# %% [markdown]
# # EXTRACT EVENTS FROM EM-DAT
#
# Database downloaded using an account at https://www.emdat.be/

# %%
import pandas as pd
import numpy as np
import requests
import json
import datetime
import re
import io
import csv
import os

# %%
def import_file_as_dataframe(FILENAME, path):
    
    INPUT_FILE = path + FILENAME
    
    #Read data from file without converting dates
    with open(INPUT_FILE) as f:
        data = json.load(f)
        data = pd.DataFrame(data)

    return data

# %%
# Changing format to emdat dataframes

def format_emdat(data):
    
    data['start_date'] = pd.to_datetime(data['start_date'], format='%d/%m/%Y', errors='coerce')
    data['end_date'] = pd.to_datetime(data['end_date'], format='%d/%m/%Y', errors='coerce')
    data.index = data.pop('start_date')
    
    return data

# %%
data = import_file_as_dataframe('2019.json', './data/EMDAT/')
data = format_emdat(data)
data.head()
# Out:
#              end_date country_name  iso                              location  \
# start_date
# 2018-05-09 2018-05-22  Afghanistan  AFG
# 2018-07-12 2018-07-12  Afghanistan  AFG             khenj district (Panjshir)
# 2018-05-07 2018-05-15  Afghanistan  AFG
# 2018-07-12 2018-07-12  Afghanistan  AFG   Peshghor (Khenj district, Panjshir)
# 2018-08-24 2018-08-24  Afghanistan  AFG  Ghazi-Abad district (Kunar province)
#
#            latitude longitude dis_mag_value dis_mag_scale   dis_type  \
# start_date
# 2018-05-09    34.94    68.216      184396.9           Km2      Flood
# 2018-07-12                                                 Landslide
# 2018-05-07                                            Km2      Flood
# 2018-07-12                                                 Landslide
# 2018-08-24                                            Km2      Flood
#
#             dis_subtype total_deaths total_affected total_dam insured_losses  \
# start_date
# 2018-05-09           --           72           4000         0              0
# 2018-07-12     Mudslide           12              0         0              0
# 2018-05-07           --           18              0         0              0
# 2018-07-12     Mudslide           10           2750         0              0
# 2018-08-24  Flash flood           11              0         0              0
#
#            event_name disaster_no associated_dis associated_dis2
# start_date
# 2018-05-09              2018-0156             --              --
# 2018-07-12              2018-0189             --              --
# 2018-05-07              2018-0212             --              --
# 2018-07-12              2018-0242             --              --
# 2018-08-24              2018-0350             --              --

# %%
data = data.drop(columns=['associated_dis2', 'dis_mag_scale', 'iso', 'dis_type', 'insured_losses', 'total_dam', 'event_name'])

# %%
data = data.loc['2018-08-01':'2019-04-01'] #Select events within the range we are interested in

# %%
data.head()
# Out:
#              end_date country_name  \
# start_date
# 2018-08-24 2018-08-24  Afghanistan
# 2019-01-06 2019-01-06  Afghanistan
# 2019-03-02        NaT  Afghanistan
# 2019-03-18 2019-03-26  Afghanistan
# 2019-02-20 2019-02-28       Angola
#
#                                                      location latitude  \
# start_date
# 2018-08-24               Ghazi-Abad district (Kunar province)
# 2019-01-06            Kohistan district (Badakhshan province)
# 2019-03-02  Zheri, Dand,Damand, Arghandab, Spinboldak,Takh...   31.991
# 2019-03-18  Herat, Ghoryan, Koh Zor, Rubat Sangi , Zinda J...
# 2019-02-20  Cangadala, Cambundi-Catembo, Quirima (Malanje ...
#
#            longitude dis_mag_value  dis_subtype total_deaths total_affected  \
# start_date
# 2018-08-24                          Flash flood           11              0
# 2019-01-06                          Flash flood           30              0
# 2019-03-02    67.078      441236.3           --           63         129100
# 2019-03-18                                   --           35              0
# 2019-02-20                          Flash flood           11           4255
#
#            disaster_no                 associated_dis
# start_date
# 2018-08-24   2018-0350                             --
# 2019-01-06   2019-0050           Industrial accidents
# 2019-03-02   2019-0082  Slide (land, mud, snow, rock)
# 2019-03-18   2019-0125                             --
# 2019-02-20   2019-0070                             --

# %%
data = data.sort_values(by='start_date')

# %%
list(data.columns.values)
# Out:
# ['end_date',
#  'country_name',
#  'location',
#  'latitude',
#  'longitude',
#  'dis_mag_value',
#  'dis_subtype',
#  'total_deaths',
#  'total_affected',
#  'disaster_no',
#  'associated_dis']

# %%
data.rename(columns={'country_name': 'countries', 'total_deaths': 'deaths', 'dis_mag_value': 'area', 'longitude': 'long', 'latitude': 'lat', 'disaster_no': 'id_emdat', 'dis_subtype': 'type', 'total_affected': 'affected', 'associated_dis': 'cause', 'location': 'locations'}, inplace=True)
data.rename_axis('start_date', inplace=True)

data.head()
# Out:
#              end_date                           countries  \
# start_date
# 2018-08-01 2018-08-10  Venezuela (Bolivarian Republic of)
# 2018-08-01 2018-09-04                         Sudan (the)
# 2018-08-02 2018-08-06                               India
# 2018-08-07 2018-08-19                                Mali
# 2018-08-07 2018-08-20                               India
#
#                                                     locations     lat    long  \
# start_date
# 2018-08-01                  Bolivar, Monagas, Amazonas states
# 2018-08-01                   Kassala, West Kordofan, Khartoum  13.487  31.942
# 2018-08-02  Biswanath, Udalguri, Golaghat, Sivassagar/Char...
# 2018-08-07  Kayes city, Goumera village, Kita city (Kayes)...
# 2018-08-07  Thrissur, Chengannur (Kerala state); West Beng...
#
#                  area         type deaths  affected   id_emdat  \
# start_date
# 2018-08-01                      --      0      9700  2018-0290
# 2018-08-01  629241.72  Flash flood     23     70060  2018-0387
# 2018-08-02                      --      3     25000  2018-0345
# 2018-08-07                      --      0     13150  2018-0441
# 2018-08-07             Flash flood    504  23220000  2018-0295
#
#                                     cause
# start_date
# 2018-08-01                             --
# 2018-08-01                             --
# 2018-08-02                             --
# 2018-08-07                             --
# 2018-08-07  Slide (land, mud, snow, rock)

# %%
data['in_emdat'] = 1 #Source identifier for future merging

# %%
outfile = './data/databases/emdat.csv'
data.to_csv(outfile, sep=',')
